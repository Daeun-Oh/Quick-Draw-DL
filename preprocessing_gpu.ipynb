# %%
import torch
from torchvision import transforms
import numpy as np
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

files = [(path, path.replace("data_original\\", "").replace(".npy", "")) for path in glob("data_original/*")]

# 분류 정보 처리
categories = [category for _, category in files]
np.save('category.npy', np.array(categories))

# 이미지 변환용 transform 정의
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=3),  # 흑백을 3채널로 변경
    transforms.ToTensor(),  # 0~1 float tensor (3,224,224)
])

for path, _ in files:
    print('-' * 10, path, '변환 시작', '-' * 10)
    data = np.load(path)
    data = data[:15000].reshape(-1, 28, 28)
    total = data.shape[0]
    
    resized_data = torch.zeros((total, 3, 224, 224), dtype=torch.uint8, device=device)
    
    for i in range(total):
        img_np = data[i]
        # numpy -> tensor 변환, transform 적용
        img_tensor = torch.from_numpy(img_np).to(device)
        img_rgb = transform(img_tensor).to(device)  # float tensor (3,224,224)
        img_rgb = (img_rgb * 255).to(torch.uint8)
        resized_data[i] = img_rgb

    # CPU로 이동 후 numpy 변환하여 저장
    resized_data_np = resized_data.cpu().numpy()

    np.save(path.replace("_original", ""), resized_data_np[:13000])
    np.save(path.replace("_original", "_val"), resized_data_np[13000:])
    
    print('-' * 10, path, '변환 종료', '-' * 10)

# 변환 이미지 테스트
items = np.load("data/aircraft carrier.npy")  # (13000, 3, 224, 224)

# matplotlib는 (H,W,C) uint8 배열을 요구하므로 차원 변환
img = items[0].transpose(1, 2, 0)  # (224,224,3)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# ---------- data_original\aircraft carrier.npy 변환 시작 ----------
# ---------- data_original\aircraft carrier.npy 변환 종료 ----------
# ---------- data_original\airplane.npy 변환 시작 ----------
# ---------- data_original\airplane.npy 변환 종료 ----------
# ---------- data_original\alarm clock.npy 변환 시작 ----------
# ---------- data_original\alarm clock.npy 변환 종료 ----------
# ---------- data_original\ambulance.npy 변환 시작 ----------
# ---------- data_original\ambulance.npy 변환 종료 ----------
# ---------- data_original\angel.npy 변환 시작 ----------
# ---------- data_original\angel.npy 변환 종료 ----------
# ---------- data_original\animal migration.npy 변환 시작 ----------
# ---------- data_original\animal migration.npy 변환 종료 ----------
# ---------- data_original\ant.npy 변환 시작 ----------
# ---------- data_original\ant.npy 변환 종료 ----------
# ---------- data_original\anvil.npy 변환 시작 ----------
# ---------- data_original\anvil.npy 변환 종료 ----------
# ---------- data_original\apple.npy 변환 시작 ----------
# ---------- data_original\apple.npy 변환 종료 ----------
# ---------- data_original\arm.npy 변환 시작 ----------
# ---------- data_original\arm.npy 변환 종료 ----------
# ---------- data_original\asparagus.npy 변환 시작 ----------
# ---------- data_original\asparagus.npy 변환 종료 ----------
# ---------- data_original\axe.npy 변환 시작 ----------
# ---------- data_original\axe.npy 변환 종료 ----------
# ---------- data_original\backpack.npy 변환 시작 ----------
# ---------- data_original\backpack.npy 변환 종료 ----------
# ---------- data_original\banana.npy 변환 시작 ----------
# ---------- data_original\banana.npy 변환 종료 ----------
# ---------- data_original\barn.npy 변환 시작 ----------
# ---------- data_original\barn.npy 변환 종료 ----------
# ---------- data_original\baseball bat.npy 변환 시작 ----------
# ---------- data_original\baseball bat.npy 변환 종료 ----------
# ---------- data_original\baseball.npy 변환 시작 ----------
# ---------- data_original\baseball.npy 변환 종료 ----------
# ---------- data_original\basket.npy 변환 시작 ----------
# ---------- data_original\basket.npy 변환 종료 ----------
# ---------- data_original\basketball.npy 변환 시작 ----------
# ---------- data_original\basketball.npy 변환 종료 ----------
# ---------- data_original\bat.npy 변환 시작 ----------
# ---------- data_original\bat.npy 변환 종료 ----------
# ---------- data_original\bathtub.npy 변환 시작 ----------
# ---------- data_original\bathtub.npy 변환 종료 ----------
# ---------- data_original\beach.npy 변환 시작 ----------
# ---------- data_original\beach.npy 변환 종료 ----------
# ---------- data_original\bear.npy 변환 시작 ----------
# ---------- data_original\bear.npy 변환 종료 ----------
# ---------- data_original\beard.npy 변환 시작 ----------
# ---------- data_original\beard.npy 변환 종료 ----------
# ---------- data_original\bed.npy 변환 시작 ----------
# ---------- data_original\bed.npy 변환 종료 ----------
# ---------- data_original\bee.npy 변환 시작 ----------
# ---------- data_original\bee.npy 변환 종료 ----------
# ---------- data_original\belt.npy 변환 시작 ----------
# ---------- data_original\belt.npy 변환 종료 ----------
# ---------- data_original\bench.npy 변환 시작 ----------
# ---------- data_original\bench.npy 변환 종료 ----------
# ---------- data_original\bicycle.npy 변환 시작 ----------
# ---------- data_original\bicycle.npy 변환 종료 ----------
# ---------- data_original\binoculars.npy 변환 시작 ----------
# ---------- data_original\binoculars.npy 변환 종료 ----------
# ---------- data_original\bird.npy 변환 시작 ----------
# ---------- data_original\bird.npy 변환 종료 ----------
# ---------- data_original\birthday cake.npy 변환 시작 ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 36
#      34 # numpy -> tensor 변환, transform 적용
#      35 img_tensor = torch.from_numpy(img_np).to(device)
# ---> 36 img_rgb = transform(img_tensor).to(device)  # float tensor (3,224,224)
#      37 img_rgb = (img_rgb * 255).to(torch.uint8)
#      38 resized_data[i] = img_rgb
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torchvision\transforms\transforms.py:1573, in Grayscale.forward(self, img)
#    1565 def forward(self, img):
#    1566     """
#    1567     Args:
#    1568         img (PIL Image or Tensor): Image to be converted to grayscale.
#    (...)
#    1571         PIL Image or Tensor: Grayscaled image.
#    1572     """
# -> 1573     return F.rgb_to_grayscale(img, num_output_channels=self.num_output_channels)
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torchvision\transforms\functional.py:1274, in rgb_to_grayscale(img, num_output_channels)
#    1272     _log_api_usage_once(rgb_to_grayscale)
#    1273 if not isinstance(img, torch.Tensor):
# -> 1274     return F_pil.to_grayscale(img, num_output_channels)
#    1276 return F_t.rgb_to_grayscale(img, num_output_channels)
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\torchvision\transforms\_functional_pil.py:343, in to_grayscale(img, num_output_channels)
#     341     img = img.convert("L")
#     342     np_img = np.array(img, dtype=np.uint8)
# --> 343     np_img = np.dstack([np_img, np_img, np_img])
#     344     img = Image.fromarray(np_img, "RGB")
#     345 else:
#
# File c:\Users\User\Desktop\Quick-Draw-DL\.venv\lib\site-packages\numpy\lib\shape_base.py:715, in dstack(tup)
#     713 if not isinstance(arrs, list):
#     714     arrs = [arrs]
# --> 715 return _nx.concatenate(arrs, 2)
#
# KeyboardInterrupt:
